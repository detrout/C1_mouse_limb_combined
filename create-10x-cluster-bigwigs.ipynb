# %% [markdown]
# # Introduction

# %% [markdown]
# Barbara would like to generate 10x cluster bigwigs

# %%
import pandas
import os
import csv
import sys
import numpy
from scipy.sparse import dok_matrix
from collections import namedtuple
import pysam

# %%
CellBarcode = namedtuple('CellBarcode', ['run', 'stage', 'barcode', 'cluster'])

# %%
def parse_barcode_csv(filename, limit=None):
    with open(filename) as barcodes:
        reader = csv.reader(barcodes)
        header = next(reader)
        for i, row in enumerate(reader):
            run = []
            stage = []
            field0 = row[0]
            run_ = field0.find('_') + 1
            for c in field0[4:run_-1]:
                run.append(c)
            # +2 to be one after the trailing 0 or 5
            run_2 = field0.find('_', run_) + 2
            for c in field0[run_:run_2]:
                if c == '_':
                    c = '.'
                stage.append(c)
            run = ''.join(run)
            stage = ''.join(stage)

            barcode = field0[run_2:-2] + '-' + field0[-1:]
            cluster = row[1]
            yield CellBarcode(run, stage, barcode, cluster)
            if limit is not None and i > limit:
                break

# %%
def build_cluster_recognizer(filename):
    clusters = {}

    for row in parse_barcode_csv(filename):
        run = clusters.setdefault(row.cluster, {})
        barcode_tree = run.setdefault(row.run, {})
        barcode_node = barcode_tree
        for c in row.barcode:
            barcode_node = barcode_node.setdefault(c, {})
        
    return clusters

# %%
clusters = build_cluster_recognizer('monocle/mouse/barcodes-to-cluster.csv')

# %%
len(clusters)
# Out:
# 25

# %%
{x: len(clusters[x]) for x in clusters}
# Out:
# {'3': 8,
#  '2': 9,
#  '5': 9,
#  '6': 7,
#  '1': 9,
#  '9': 9,
#  '24': 7,
#  '0': 9,
#  '13': 9,
#  '4': 8,
#  '17': 8,
#  '22': 6,
#  '8': 9,
#  '14': 8,
#  '21': 8,
#  '12': 7,
#  '11': 6,
#  '7': 8,
#  '18': 9,
#  '10': 8,
#  '20': 7,
#  '15': 9,
#  '23': 8,
#  '19': 8,
#  '16': 5}

# %%
{x: len(clusters['17'][x]) for x in clusters['17']}
# Out:
# {'12': 4, '13': 4, '1': 4, '4': 4, '5': 4, '6': 4, '7': 1, '8': 4}

# %% [markdown]
# Try to figure out how to build a sparse matrix that counts reads

# %%
chr19 = dok_matrix((1,61431566))

# %%
chr19[0, 100:150] += 1

# %%
chr19[0, 125:175] += 1

# %%
for y in chr19.nonzero()[1]:
    print(y, chr19[0,y])
# Out:
# 100 1.0
# 101 1.0
# 102 1.0
# 103 1.0
# 104 1.0
# 105 1.0
# 106 1.0
# 107 1.0
# 108 1.0
# 109 1.0
# 110 1.0
# 111 1.0
# 112 1.0
# 113 1.0
# 114 1.0
# 115 1.0
# 116 1.0
# 117 1.0
# 118 1.0
# 119 1.0
# 120 1.0
# 121 1.0
# 122 1.0
# 123 1.0
# 124 1.0
# 125 2.0
# 126 2.0
# 127 2.0
# 128 2.0
# 129 2.0
# 130 2.0
# 131 2.0
# 132 2.0
# 133 2.0
# 134 2.0
# 135 2.0
# 136 2.0
# 137 2.0
# 138 2.0
# 139 2.0
# 140 2.0
# 141 2.0
# 142 2.0
# 143 2.0
# 144 2.0
# 145 2.0
# 146 2.0
# 147 2.0
# 148 2.0
# 149 2.0
# 150 1.0
# 151 1.0
# 152 1.0
# 153 1.0
# 154 1.0
# 155 1.0
# 156 1.0
# 157 1.0
# 158 1.0
# 159 1.0
# 160 1.0
# 161 1.0
# 162 1.0
# 163 1.0
# 164 1.0
# 165 1.0
# 166 1.0
# 167 1.0
# 168 1.0
# 169 1.0
# 170 1.0
# 171 1.0
# 172 1.0
# 173 1.0
# 174 1.0

# %%
def build_sparse_genome(filename):
    chroms = {}
    with open(filename, 'rt') as chromInfo:
        for line in chromInfo:
            name, length = line.rstrip().split()
            chroms[name] = dok_matrix((1,int(length)))
    return chroms

# %%
def is_recognized_barcode(barcode_tree, cell_barcode):
    barcode_node = barcode_tree
    for c in cell_barcode:
        try:
            barcode_node = barcode_node[c]
        except KeyError:
            return False
    return True

# %%
is_recognized_barcode(clusters['17']['12'], 'AACACGTAGAGTGAGA-1')
# Out:
# True

# %%
clusters['17']['12']['A']['A']['C']['A']['C']['G']['T']['A']['G']['A']['G']['T']['G']['A']['G']['A']['-']['1']
# Out:
# {}

# %%
def update_sparse_wiggle(wiggle, bam, barcode_tree, limit=None):
    for i, read in enumerate(bam):
        if not read.is_unmapped and read.has_tag('CB'):
            cb = read.get_tag('CB')
            if is_recognized_barcode(barcode_tree, cb):
                for pos in read.get_reference_positions():
                    wiggle[read.reference_name][0, pos] += 1
                    
        if limit is not None and i > limit:
            break

# %%
chroms = build_sparse_genome(os.path.expanduser('~/proj/genome/mm10-M4-male/chrNameLength.txt'))

# %%
possort = pysam.AlignmentFile(os.path.expanduser('~/proj/brian-2018-01-10x/Wold10x-12-encode-count-cells10000/outs/possorted_genome_bam.bam'))

# %%
update_sparse_wiggle(chroms, possort, clusters['17']['12'])

# %%
chroms
# Out:
# {'chr10': <1x130694993 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3525343 stored elements in Dictionary Of Keys format>,
#  'chr11': <1x122082543 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5006272 stored elements in Dictionary Of Keys format>,
#  'chr12': <1x120129022 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3030416 stored elements in Dictionary Of Keys format>,
#  'chr13': <1x120421639 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3071452 stored elements in Dictionary Of Keys format>,
#  'chr14': <1x124902244 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2822347 stored elements in Dictionary Of Keys format>,
#  'chr15': <1x104043685 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2637571 stored elements in Dictionary Of Keys format>,
#  'chr16': <1x98207768 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2526726 stored elements in Dictionary Of Keys format>,
#  'chr17': <1x94987271 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3013234 stored elements in Dictionary Of Keys format>,
#  'chr18': <1x90702639 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2444350 stored elements in Dictionary Of Keys format>,
#  'chr19': <1x61431566 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2089870 stored elements in Dictionary Of Keys format>,
#  'chr1': <1x195471971 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4655757 stored elements in Dictionary Of Keys format>,
#  'chr2': <1x182113224 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5978494 stored elements in Dictionary Of Keys format>,
#  'chr3': <1x160039680 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3943879 stored elements in Dictionary Of Keys format>,
#  'chr4': <1x156508116 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4566552 stored elements in Dictionary Of Keys format>,
#  'chr5': <1x151834684 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4737469 stored elements in Dictionary Of Keys format>,
#  'chr6': <1x149736546 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3692445 stored elements in Dictionary Of Keys format>,
#  'chr7': <1x145441459 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4205279 stored elements in Dictionary Of Keys format>,
#  'chr8': <1x129401213 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3559232 stored elements in Dictionary Of Keys format>,
#  'chr9': <1x124595110 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4100548 stored elements in Dictionary Of Keys format>,
#  'chrM': <1x16299 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16211 stored elements in Dictionary Of Keys format>,
#  'chrX': <1x171031299 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2734565 stored elements in Dictionary Of Keys format>,
#  'chrY': <1x91744698 sparse matrix of type '<class 'numpy.float64'>'
#  	with 97866 stored elements in Dictionary Of Keys format>,
#  'ERCC-00002': <1x1061 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00003': <1x1023 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00004': <1x523 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00007': <1x1135 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00009': <1x984 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00012': <1x994 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00013': <1x808 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00014': <1x1957 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00016': <1x844 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00017': <1x1136 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00018': <1x1032 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00019': <1x644 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00022': <1x751 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00023': <1x273 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00024': <1x536 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00025': <1x1994 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00028': <1x1130 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00031': <1x1138 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00033': <1x2022 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00034': <1x1019 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00035': <1x1130 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00039': <1x740 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00040': <1x744 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00041': <1x1122 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00042': <1x1023 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00043': <1x1023 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00044': <1x1156 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00046': <1x522 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00048': <1x992 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00051': <1x274 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00053': <1x1023 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00054': <1x274 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00057': <1x1021 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00058': <1x1136 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00059': <1x525 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00060': <1x523 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00061': <1x1136 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00062': <1x1023 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00067': <1x644 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00069': <1x1137 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00071': <1x642 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00073': <1x603 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00074': <1x522 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00075': <1x1023 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00076': <1x642 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00077': <1x273 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00078': <1x993 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00079': <1x644 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00081': <1x534 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00083': <1x1022 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00084': <1x994 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00085': <1x844 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00086': <1x1020 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00092': <1x1124 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00095': <1x521 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00096': <1x1107 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00097': <1x523 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00098': <1x1143 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00099': <1x1350 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00104': <1x2022 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00108': <1x1022 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00109': <1x536 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00111': <1x994 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00112': <1x1136 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00113': <1x840 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00116': <1x1991 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00117': <1x1136 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00120': <1x536 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00123': <1x1022 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00126': <1x1118 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00128': <1x1133 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00130': <1x1059 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00131': <1x771 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00134': <1x274 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00136': <1x1033 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00137': <1x537 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00138': <1x1024 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00142': <1x493 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00143': <1x784 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00144': <1x538 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00145': <1x1042 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00147': <1x1023 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00148': <1x494 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00150': <1x743 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00154': <1x537 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00156': <1x494 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00157': <1x1019 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00158': <1x1027 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00160': <1x743 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00162': <1x523 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00163': <1x543 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00164': <1x1022 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00165': <1x872 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00168': <1x1024 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00170': <1x1023 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>,
#  'ERCC-00171': <1x505 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Dictionary Of Keys format>}

# %%
chroms['chr10']
# Out:
# <1x130694993 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2037495 stored elements in Dictionary Of Keys format>

# %%
for i,y in enumerate(chroms['chr10'].nonzero()[1]):
    print(y, chroms['chr10'][0,y])
    if i > 1000:
        break
# Out:
# 3165723 1.0
# 3165724 1.0
# 3165725 1.0
# 3165726 1.0
# 3165727 1.0
# 3165728 1.0
# 3165729 1.0
# 3165730 1.0
# 3165731 1.0
# 3165732 1.0
# 3165733 1.0
# 3165734 1.0
# 3165735 1.0
# 3165736 1.0
# 3165737 1.0
# 3165738 1.0
# 3268399 1.0
# 3268400 1.0
# 3268401 1.0
# 3268402 1.0
# 3268403 1.0
# 3268404 1.0
# 3268405 1.0
# 3268406 1.0
# 3268407 1.0
# 3268408 1.0
# 3268409 1.0
# 3268410 1.0
# 3268411 1.0
# 3268412 1.0
# 3268413 1.0
# 3268414 1.0
# 3268415 1.0
# 3268416 1.0
# 3268417 1.0
# 3268418 1.0
# 3268419 1.0
# 3268420 1.0
# 3268421 1.0
# 3268422 1.0
# 3268423 1.0
# 3268424 1.0
# 3268425 1.0
# 3268426 1.0
# 3268427 1.0
# 3268428 1.0
# 3268429 1.0
# 3268430 1.0
# 3268431 1.0
# 3268432 1.0
# 3268433 1.0
# 3268434 1.0
# 3268435 1.0
# 3268436 1.0
# 3268437 1.0
# 3268438 1.0
# 3268439 1.0
# 3268440 1.0
# 3268441 1.0
# 3268442 1.0
# 3268443 1.0
# 3268444 1.0
# 3268445 1.0
# 3268446 1.0
# 3268447 1.0
# 3268448 1.0
# 3268449 1.0
# 3268450 1.0
# 3268451 1.0
# 3268452 1.0
# 3268453 1.0
# 3268454 1.0
# 3268455 1.0
# 3268456 1.0
# 3268457 1.0
# 3268458 1.0
# 3268459 1.0
# 3268460 1.0
# 3268461 1.0
# 3268462 1.0
# 3268463 1.0
# 3268464 1.0
# 3268465 1.0
# 3268466 1.0
# 3268467 1.0
# 3268468 1.0
# 3268469 1.0
# 3268470 1.0
# 3268471 1.0
# 3268472 1.0
# 3268473 1.0
# 3268474 1.0
# 3268475 1.0

# %% [markdown]
# # build barcode pattern list

# %%
def create_cluster_run_barcode_lists(filename, cluster, output_template):
    run_streams = {}
    for row in parse_barcode_csv(filename):
        if row.cluster == cluster:
            output = output_template.format(cluster=row.cluster, run=row.run)
            outstream = run_streams.setdefault(row.run, open(output, 'wt'))
            outstream.write('CB:Z:')
            outstream.write(row.barcode)
            outstream.write(os.linesep)
            
    for name in run_streams:
        run_streams[name].close()

# %%
create_cluster_run_barcode_lists(
    'monocle/mouse/barcodes-to-cluster.csv',
    '17',
    '10x_tracks/barcodes-10x-cluster-{cluster}-run-{run}.txt',
)

# %%
create_cluster_run_barcode_lists(
    'monocle/mouse/barcodes-to-cluster.csv',
    '12',
    '10x_tracks/barcodes-10x-cluster-{cluster}-run-{run}.txt',
)

# %%
create_cluster_run_barcode_lists(
    'monocle/mouse/barcodes-to-cluster.csv',
    '4',
    '10x_tracks/barcodes-10x-cluster-{cluster}-run-{run}.txt',
)

# %%
create_cluster_run_barcode_lists(
    'monocle/mouse/barcodes-to-cluster.csv',
    '2',
    '10x_tracks/barcodes-10x-cluster-{cluster}-run-{run}.txt',
)

# %%
create_cluster_run_barcode_lists(
    'monocle/mouse/barcodes-to-cluster.csv',
    '0',
    '10x_tracks/barcodes-10x-cluster-{cluster}-run-{run}.txt',
)

# %%
create_cluster_run_barcode_lists(
    'monocle/mouse/barcodes-to-cluster.csv',
    '7',
    '10x_tracks/barcodes-10x-cluster-{cluster}-run-{run}.txt',
)
