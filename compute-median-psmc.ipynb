# %%
import os
import pandas
import numpy

# %%
psmc_by_run_tsv = os.path.expanduser('~diane/public_html/C1_mouse_limb_likelihoods/psmc_by_run.tsv')
psmc_by_run = pandas.read_csv(psmc_by_run_tsv, sep='\t')
psmc_by_run.head()
# Out:
#           label    cell_id  Psmc
# 0  run  3 e10.5  18089_H12  0.01
# 1  run  3 e10.5   18089_H7  0.89
# 2  run  3 e10.5   18087_F6  0.84
# 3  run  3 e10.5   18088_G9  0.80
# 4  run  3 e10.5  18087_F10  0.66

# %%
psmc_by_run.groupby('label').aggregate(numpy.median)
# Out:
#                Psmc
# label
# run  3 e10.5  0.460
# run  4 e13.5  0.450
# run  5 e11.0  0.440
# run  6 e11.5  0.530
# run  7 e12.5  0.640
# run  8 e13.5  0.395
# run 10 e11.5  0.555
# run 11 e12.0  0.610
# run 12 e13.0  0.620
# run 13 e14.0  0.480
# run 14 e15.5  0.735
# run 15 e10.5  0.585
# run 16 e11.0  0.410
# run 17 e14.5  0.530
