# %% [markdown]
# # Introduction

# %% [markdown]
# We need to submit the processed data that was used in our paper to the DCC so other people can investigate what we did, and unfortunately since my pipeline is slightly different from theirs I need to send my actual processed results.

# %%
import hashlib
import pandas
import sys
import os
import numpy
from base64 import b64encode
from pprint import pprint

# %%
from woldrnaseq import models
from woldrnaseq.common import validate_reference_type

# %%
HTSW=os.path.expanduser('~diane/proj/htsworkflow')
if HTSW not in sys.path:
    sys.path.append(HTSW)
from htsworkflow.submission import encoded

# %%
server = encoded.ENCODED('www.encodeproject.org')
#server = encoded.ENCODED('test.encodedcc.org')
server.load_netrc()
validator = encoded.DCCValidator(server)

# %%
uploaded_raw_sheet_filename = 'C1-mouse-forelimb-submission-201907-uploaded-production.xlsx'
uploaded = pandas.ExcelFile(uploaded_raw_sheet_filename)

# %%
uploaded.sheet_names
# Out:
# ['Biosample', 'Library', 'Experiment', 'Replicate', 'File']

# %%
submitted_experiment = uploaded.parse('Experiment')
submitted_libraries = uploaded.parse('Library')
submitted_replicates = uploaded.parse('Replicate')
submitted_files = uploaded.parse('File')

# %%
metadata = submitted_replicates.merge(
    submitted_experiment[['accession', 'aliases:array']].rename({'aliases:array': 'aliases:experiment'}, axis=1),
    left_on='experiment', right_on='aliases:experiment').merge(
        submitted_files.rename({'accession': 'file_accession'}, axis=1),
        left_on='aliases:array', right_on='replicate')
metadata.head()
# Out:
#                                    uuid  \
# 0  bf273ae5-72b5-4237-b03b-a9e68fb56f5c
# 1  bf273ae5-72b5-4237-b03b-a9e68fb56f5c
# 2  af8e4fc1-7a4f-49c3-b5f6-8c4fbcae92de
# 3  af8e4fc1-7a4f-49c3-b5f6-8c4fbcae92de
# 4  2990357c-2cec-4bf7-ac5d-709a14f39ea8
#
#                                         experiment  \
# 0   barbara-wold:c1_e10.5_mouse_limb_run2_17327_A1
# 1   barbara-wold:c1_e10.5_mouse_limb_run2_17327_A1
# 2  barbara-wold:c1_e10.5_mouse_limb_run2_17327_A10
# 3  barbara-wold:c1_e10.5_mouse_limb_run2_17327_A10
# 4  barbara-wold:c1_e10.5_mouse_limb_run2_17327_A11
#
#    biological_replicate_number:integer  technical_replicate_number:integer  \
# 0                                    1                                   1
# 1                                    1                                   1
# 2                                    1                                   1
# 3                                    1                                   1
# 4                                    1                                   1
#
#                   library                 aliases:array    accession  \
# 0   barbara-wold:17327_A1   barbara-wold:17327_A1_b1_t1  ENCSR316KIY
# 1   barbara-wold:17327_A1   barbara-wold:17327_A1_b1_t1  ENCSR316KIY
# 2  barbara-wold:17327_A10  barbara-wold:17327_A10_b1_t1  ENCSR541RSL
# 3  barbara-wold:17327_A10  barbara-wold:17327_A10_b1_t1  ENCSR541RSL
# 4  barbara-wold:17327_A11  barbara-wold:17327_A11_b1_t1  ENCSR736TCS
#
#                                 aliases:experiment file_accession  \
# 0   barbara-wold:c1_e10.5_mouse_limb_run2_17327_A1    ENCFF791VYN
# 1   barbara-wold:c1_e10.5_mouse_limb_run2_17327_A1    ENCFF272GSE
# 2  barbara-wold:c1_e10.5_mouse_limb_run2_17327_A10    ENCFF875SEA
# 3  barbara-wold:c1_e10.5_mouse_limb_run2_17327_A10    ENCFF065ITR
# 4  barbara-wold:c1_e10.5_mouse_limb_run2_17327_A11    ENCFF753EDK
#
#                                            dataset  \
# 0   barbara-wold:c1_e10.5_mouse_limb_run2_17327_A1
# 1   barbara-wold:c1_e10.5_mouse_limb_run2_17327_A1
# 2  barbara-wold:c1_e10.5_mouse_limb_run2_17327_A10
# 3  barbara-wold:c1_e10.5_mouse_limb_run2_17327_A10
# 4  barbara-wold:c1_e10.5_mouse_limb_run2_17327_A11
#
#                ...               \
# 0              ...
# 1              ...
# 2              ...
# 3              ...
# 4              ...
#
#                                flowcell_details:json read_length:integer  \
# 0  [{"machine": "http://jumpgate.caltech.edu/sequ...                  50
# 1  [{"machine": "http://jumpgate.caltech.edu/sequ...                  50
# 2  [{"machine": "http://jumpgate.caltech.edu/sequ...                  50
# 3  [{"machine": "http://jumpgate.caltech.edu/sequ...                  50
# 4  [{"machine": "http://jumpgate.caltech.edu/sequ...                  50
#
#   file_size:integer           lab        award  file_format output_type  \
# 0          76952708  barbara-wold  UM1HG009443        fastq       reads
# 1          78307437  barbara-wold  UM1HG009443        fastq       reads
# 2          30471929  barbara-wold  UM1HG009443        fastq       reads
# 3          29889475  barbara-wold  UM1HG009443        fastq       reads
# 4          86476491  barbara-wold  UM1HG009443        fastq       reads
#
#            platform library_id:skip                     replicate
# 0  encode:HiSeq2500        17327_A1   barbara-wold:17327_A1_b1_t1
# 1  encode:HiSeq2500        17327_A1   barbara-wold:17327_A1_b1_t1
# 2  encode:HiSeq2500       17327_A10  barbara-wold:17327_A10_b1_t1
# 3  encode:HiSeq2500       17327_A10  barbara-wold:17327_A10_b1_t1
# 4  encode:HiSeq2500       17327_A11  barbara-wold:17327_A11_b1_t1
#
# [5 rows x 23 columns]

# %%
libraries = models.load_library_tables(['all_analysis_vdir/library-passing.tsv'])
experiments = models.load_experiments(['all_analysis_vdir/experiment_vdir.tsv'])
# Out:
# Unrecognized columns present. Is this intended?: analysis_name

# %%
def get_attachment(filename, mime_type):
    with open(filename, 'rb') as instream:
        contents = instream.read()
        payload = "data:{};base64,{}".format(
            mime_type, 
            b64encode(contents).decode("ascii"))
        obj = {
            "type": mime_type,
            "download": filename.split("/")[-1] + '.txt',
            "href": payload,
            #"size": len(contents),
            #"md5sum": hashlib.md5(contents).hexdigest(),
        }
        return obj

def generate_flagstat_object(library, reference_type):
    suffix_map = {
        'genome': 'genome',
        'transcriptome': 'anno',
    }
    triplet = models.genome_name_from_library(library)
    suffix = suffix_map[reference_type]
    bam_alias = f'barbara-wold:{library.analysis_name}-{triplet}_{suffix}.bam'
    flagstat_filename = f'{library.analysis_name}-{triplet}_{suffix}.flagstat'
    flagstat_pathname = os.path.join('all_analysis_vdir', flagstat_filename)
    flagstat = models.load_flagstat(flagstat_pathname)
    #flagstat['@type'] = ['SamtoolsFlagstatsQualityMetric', 'QualityMetric', 'Item']
    flagstat['quality_metric_of'] = [bam_alias]
    flagstat['step_run'] = '/analysis-step-runs/ecd38dae-7937-4865-8f82-0a3829f1b249/'
    flagstat['attachment'] = get_attachment(flagstat_pathname, 'text/plain')
    flagstat['award'] = 'UM1HG009443'
    flagstat['lab'] = '/labs/barbara-wold/'
    return flagstat

# %%
def has_flagstat(server, bam):
    obj = server.get_json(bam, datastore='database')
    for metric in obj.get('quality_metrics', []):
        if 'SamtoolsFlagstatsQualityMetric' in metric['@type']:
            return True
    return False

# %%
genome_flagstat = generate_flagstat_object(libraries.iloc[0], 'genome')
pprint(genome_flagstat)
validator.validate(genome_flagstat, 'SamtoolsFlagstatsQualityMetric')
# Out:
# {'attachment': {'download': '19906_A5-mm10-M4-male_genome.flagstat.txt',
#                 'href': 'data:text/plain;base64,...',
#                 'type': 'text/plain'},
#  'award': 'UM1HG009443',
#  'duplicates': 0,
#  'duplicates_qc_failed': 0,
#  'lab': '/labs/barbara-wold/',
#  'mapped': 1635004,
#  'mapped_pct': '97.66',
#  'mapped_qc_failed': 89807,
#  'quality_metric_of': ['barbara-wold:19906_A5-mm10-M4-male_genome.bam'],
#  'step_run': '/analysis-step-runs/ecd38dae-7937-4865-8f82-0a3829f1b249/',
#  'total': 1674256,
#  'total_qc_failed': 101288}

# %%
obj = server.get_json('barbara-wold:19906_A5-mm10-M4-male_genome.bam')

# %%
obj['quality_metrics']
# Out:
# []

# %%
obj = server.get_json('/files/ENCFF704SWF/')
[ x['@type'] for x in obj['quality_metrics']]
# Out:
# [['SamtoolsFlagstatsQualityMetric', 'QualityMetric', 'Item'],
#  ['StarQualityMetric', 'QualityMetric', 'Item']]

# %%
has_flagstat(server, 'barbara-wold:19906_A5-mm10-M4-male_genome.bam')
# Out:
# True

# %%
added_flagstat = []
flagstat_present = []
responses = {}

# %%
validator = encoded.DCCValidator(server)
processed_files = []
for library_id, lib in libraries.iterrows():
    for aligned_to in ['genome', 'transcriptome']:
        flagstat = generate_flagstat_object(lib, aligned_to)
        bam = flagstat['quality_metric_of'][0]
        if not has_flagstat(server, bam):
            print(f'adding {library_id}')
            added_flagstat.append(bam)
            validator.validate(flagstat, 'SamtoolsFlagstatsQualityMetric')
            responses[bam] = server.post_json('/samtools-flagstats-quality-metrics/', flagstat)
        else:
            flagstat_present.append(bam)

print('added', len(added_flagstat))
print('present', len(flagstat_present))
# Out:
# adding 20028_C1
# adding 20028_C1
# adding 18263_A5
# adding 18263_A5
# adding 20031_F6
# adding 20031_F6
# adding 18317_G7
# adding 18317_G7
# adding 18276_G11
# adding 18276_G11
# adding 20026_A12
# adding 20026_A12
# adding 19916_C6
# adding 19916_C6
# adding 20036_D12
# adding 20036_D12
# adding 20037_E3
# adding 20037_E3
# adding 18265_C3
# adding 18265_C3
# adding 18312_B6
# adding 18312_B6
# adding 18316_F3
# adding 18316_F3
# adding 18256_F11
# adding 18256_F11
# adding 17328_B3
# adding 17328_B3
# adding 17328_B9
# adding 17328_B9
# adding 20027_B5
# adding 18265_C11
# adding 18265_C11
# adding 18253_C5
# adding 18253_C5
# adding 19908_C1
# adding 19908_C1
# adding 18254_D3
# adding 18254_D3
# adding 17327_A5
# adding 17327_A5
# adding 18089_H9
# adding 18089_H9
# adding 18263_A1
# adding 18263_A1
# adding 18315_E1
# adding 18315_E1
# adding 20040_B12
# adding 20040_B12
# adding 18045_D11
# adding 18045_D11
# adding 18274_E5
# adding 18274_E5
# adding 20042_D9
# adding 20042_D9
# adding 18273_D11
# adding 18273_D11
# adding 20047_D1
# adding 20047_D1
# adding 20090_C11
# adding 20090_C11
# adding 18254_D4
# adding 18254_D4
# adding 18045_D2
# adding 18045_D2
# adding 18043_B12
# adding 18043_B12
# adding 18264_B7
# adding 18264_B7
# adding 19914_A2
# adding 19914_A2
# adding 20030_E2
# adding 20030_E2
# adding 18088_G2
# adding 18088_G2
# adding 19911_F1
# adding 19911_F1
# adding 17330_D4
# adding 17330_D4
# adding 19917_D6
# adding 19917_D6
# adding 17332_F4
# adding 17332_F4
# adding 19912_G3
# adding 19912_G3
# adding 20042_D5
# adding 20042_D5
# adding 20048_E12
# adding 20048_E12
# adding 18088_G4
# adding 18088_G4
# adding 17330_D10
# adding 17330_D10
# adding 18256_F6
# adding 18256_F6
# adding 18047_F12
# adding 18047_F12
# adding 18255_E1
# adding 18255_E1
# adding 18261_D1
# adding 18261_D1
# adding 18258_A5
# adding 18258_A5
# adding 20041_C8
# adding 20041_C8
# adding 18269_G1
# adding 18269_G1
# adding 18261_D3
# adding 18261_D3
# adding 18046_E4
# adding 18046_E4
# adding 20033_A6
# adding 20033_A6
# adding 18259_B12
# adding 18259_B12
# adding 18263_A10
# adding 18263_A10
# adding 18311_A9
# adding 18311_A9
# adding 20031_F3
# adding 20031_F3
# adding 18311_A10
# adding 18311_A10
# adding 18259_B4
# adding 18259_B4
# adding 18045_D3
# adding 18045_D3
# adding 19915_B12
# adding 19915_B12
# adding 18270_A11
# adding 18270_A11
# adding 18045_D7
# adding 18045_D7
# adding 20047_D7
# adding 20047_D7
# adding 20032_G2
# adding 20032_G2
# adding 17330_D8
# adding 17330_D8
# adding 17327_A6
# adding 17327_A6
# adding 18265_C5
# adding 18265_C5
# adding 18314_D5
# adding 18314_D5
# adding 20037_E8
# adding 20037_E8
# adding 20044_A3
# adding 20044_A3
# adding 19906_A2
# adding 19906_A2
# adding 19916_C7
# adding 19916_C7
# adding 19908_C8
# adding 19908_C8
# adding 17331_E11
# adding 17331_E11
# adding 17330_D6
# adding 17330_D6
# adding 20035_C11
# adding 20035_C11
# adding 18266_D4
# adding 18266_D4
# adding 20045_B8
# adding 20045_B8
# adding 18261_D4
# adding 18261_D4
# adding 18275_F4
# adding 18275_F4
# adding 18269_G3
# adding 18269_G3
# adding 20037_E11
# adding 20037_E11
# adding 18275_F7
# adding 18275_F7
# adding 18268_F9
# adding 18268_F9
# adding 18045_D12
# adding 18045_D12
# adding 18312_B7
# adding 18312_B7
# adding 18273_D3
# adding 18273_D3
# adding 20034_B5
# adding 18270_A7
# adding 18270_A7
# adding 18088_G6
# adding 18088_G6
# adding 18043_B3
# adding 18043_B3
# adding 19906_A12
# adding 19906_A12
# adding 19915_B4
# adding 19915_B4
# adding 18049_H1
# adding 18049_H1
# adding 18253_C3
# adding 18253_C3
# adding 18255_E2
# adding 18255_E2
# adding 18315_E4
# adding 18315_E4
# adding 18313_C12
# adding 18313_C12
# adding 18252_B12
# adding 18252_B12
# adding 18269_G11
# adding 18269_G11
# adding 20030_E12
# adding 20030_E12
# adding 17332_F10
# adding 17332_F10
# adding 20043_E1
# adding 20043_E1
# adding 18272_C6
# adding 18272_C6
# adding 20049_F8
# adding 20049_F8
# adding 20041_C6
# adding 20041_C6
# adding 18258_A11
# adding 18258_A11
# adding 20037_E7
# adding 20037_E7
# adding 18264_B8
# adding 18264_B8
# adding 20090_C8
# adding 20090_C8
# adding 18045_D4
# adding 18045_D4
# adding 20034_B8
# adding 20034_B8
# adding 18259_B9
# adding 18259_B9
# adding 20030_E3
# adding 20030_E3
# adding 17334_H1
# adding 17334_H1
# adding 18251_A2
# adding 18251_A2
# adding 18043_B7
# adding 18043_B7
# adding 18311_A3
# adding 18311_A3
# adding 18049_H2
# adding 18049_H2
# adding 20042_D4
# adding 20042_D4
# adding 20037_E5
# adding 20037_E5
# adding 17329_C10
# adding 17329_C10
# adding 18257_G1
# adding 18257_G1
# adding 18317_G2
# adding 18317_G2
# adding 18048_G12
# adding 18048_G12
# adding 18270_A8
# adding 18270_A8
# adding 18047_F8
# adding 18047_F8
# adding 18274_E11
# adding 18274_E11
# adding 20032_G1
# adding 20032_G1
# adding 20035_C9
# adding 20035_C9
# adding 18048_G3
# adding 18048_G3
# adding 18313_C3
# adding 18313_C3
# adding 20031_F12
# adding 20031_F12
# adding 18275_F1
# adding 18275_F1
# adding 20047_D4
# adding 20047_D4
# adding 18263_A4
# adding 18263_A4
# adding 18087_F4
# adding 18087_F4
# adding 18314_D2
# adding 18314_D2
# adding 18043_B11
# adding 18043_B11
# adding 17332_F7
# adding 17332_F7
# adding 18311_A12
# adding 18311_A12
# adding 18265_C7
# adding 18265_C7
# adding 19917_D4
# adding 19917_D4
# adding 19915_B9
# adding 19915_B9
# adding 20090_C4
# adding 20090_C4
# adding 19912_G6
# adding 19912_G6
# adding 19914_A12
# adding 19914_A12
# adding 18269_G5
# adding 18269_G5
# adding 20048_E9
# adding 20048_E9
# adding 18262_E1
# adding 18262_E1
# adding 20090_C5
# adding 20090_C5
# adding 20026_A4
# adding 20026_A4
# adding 20028_C2
# adding 20028_C2
# adding 20039_A9
# adding 20039_A9
# adding 18259_B10
# adding 18259_B10
# adding 18275_F5
# adding 18275_F5
# adding 18251_A8
# adding 18251_A8
# adding 20036_D7
# adding 20036_D7
# adding 20033_A3
# adding 20033_A3
# adding 20028_C3
# adding 20028_C3
# added 1546
# present 528

# %%
has_flagstat

# %%
i

# %%
responses['19906_A5']

# %%
has_flagstat(server, '/files/ENCFF385LEF/')
