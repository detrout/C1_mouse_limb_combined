# %% [markdown]
# # Introduction

# %% [markdown]
# We need to submit the processed data that was used in our paper to the DCC so other people can investigate what we did, and unfortunately since my pipeline is slightly different from theirs I need to send my actual processed results.

# %%
import hashlib
import pandas
import sys
import os
import numpy
from base64 import b64encode
from pprint import pprint

# %%
from woldrnaseq import models
from woldrnaseq.common import validate_reference_type

# %%
HTSW=os.path.expanduser('~diane/proj/htsworkflow')
if HTSW not in sys.path:
    sys.path.append(HTSW)
from htsworkflow.submission import encoded

# %%
#server = encoded.ENCODED('www.encodeproject.org')
server = encoded.ENCODED('test.encodedcc.org')
server.load_netrc()
validator = encoded.DCCValidator(server)

# %%
uploaded_raw_sheet_filename = 'C1-mouse-forelimb-submission-201907-uploaded-production.xlsx'
uploaded = pandas.ExcelFile(uploaded_raw_sheet_filename)

# %%
uploaded.sheet_names
# Out:
# ['Biosample', 'Library', 'Experiment', 'Replicate', 'File']

# %%
submitted_experiment = uploaded.parse('Experiment')
submitted_libraries = uploaded.parse('Library')
submitted_replicates = uploaded.parse('Replicate')
submitted_files = uploaded.parse('File')

# %%
metadata = submitted_replicates.merge(
    submitted_experiment[['accession', 'aliases:array']].rename({'aliases:array': 'aliases:experiment'}, axis=1),
    left_on='experiment', right_on='aliases:experiment').merge(
        submitted_files.rename({'accession': 'file_accession'}, axis=1),
        left_on='aliases:array', right_on='replicate')
metadata.head()
# Out:
#                                    uuid  \
# 0  bf273ae5-72b5-4237-b03b-a9e68fb56f5c
# 1  bf273ae5-72b5-4237-b03b-a9e68fb56f5c
# 2  af8e4fc1-7a4f-49c3-b5f6-8c4fbcae92de
# 3  af8e4fc1-7a4f-49c3-b5f6-8c4fbcae92de
# 4  2990357c-2cec-4bf7-ac5d-709a14f39ea8
#
#                                         experiment  \
# 0   barbara-wold:c1_e10.5_mouse_limb_run2_17327_A1
# 1   barbara-wold:c1_e10.5_mouse_limb_run2_17327_A1
# 2  barbara-wold:c1_e10.5_mouse_limb_run2_17327_A10
# 3  barbara-wold:c1_e10.5_mouse_limb_run2_17327_A10
# 4  barbara-wold:c1_e10.5_mouse_limb_run2_17327_A11
#
#    biological_replicate_number:integer  technical_replicate_number:integer  \
# 0                                    1                                   1
# 1                                    1                                   1
# 2                                    1                                   1
# 3                                    1                                   1
# 4                                    1                                   1
#
#                   library                 aliases:array    accession  \
# 0   barbara-wold:17327_A1   barbara-wold:17327_A1_b1_t1  ENCSR316KIY
# 1   barbara-wold:17327_A1   barbara-wold:17327_A1_b1_t1  ENCSR316KIY
# 2  barbara-wold:17327_A10  barbara-wold:17327_A10_b1_t1  ENCSR541RSL
# 3  barbara-wold:17327_A10  barbara-wold:17327_A10_b1_t1  ENCSR541RSL
# 4  barbara-wold:17327_A11  barbara-wold:17327_A11_b1_t1  ENCSR736TCS
#
#                                 aliases:experiment file_accession  \
# 0   barbara-wold:c1_e10.5_mouse_limb_run2_17327_A1    ENCFF791VYN
# 1   barbara-wold:c1_e10.5_mouse_limb_run2_17327_A1    ENCFF272GSE
# 2  barbara-wold:c1_e10.5_mouse_limb_run2_17327_A10    ENCFF875SEA
# 3  barbara-wold:c1_e10.5_mouse_limb_run2_17327_A10    ENCFF065ITR
# 4  barbara-wold:c1_e10.5_mouse_limb_run2_17327_A11    ENCFF753EDK
#
#                                            dataset  \
# 0   barbara-wold:c1_e10.5_mouse_limb_run2_17327_A1
# 1   barbara-wold:c1_e10.5_mouse_limb_run2_17327_A1
# 2  barbara-wold:c1_e10.5_mouse_limb_run2_17327_A10
# 3  barbara-wold:c1_e10.5_mouse_limb_run2_17327_A10
# 4  barbara-wold:c1_e10.5_mouse_limb_run2_17327_A11
#
#                ...               \
# 0              ...
# 1              ...
# 2              ...
# 3              ...
# 4              ...
#
#                                flowcell_details:json read_length:integer  \
# 0  [{"machine": "http://jumpgate.caltech.edu/sequ...                  50
# 1  [{"machine": "http://jumpgate.caltech.edu/sequ...                  50
# 2  [{"machine": "http://jumpgate.caltech.edu/sequ...                  50
# 3  [{"machine": "http://jumpgate.caltech.edu/sequ...                  50
# 4  [{"machine": "http://jumpgate.caltech.edu/sequ...                  50
#
#   file_size:integer           lab        award  file_format output_type  \
# 0          76952708  barbara-wold  UM1HG009443        fastq       reads
# 1          78307437  barbara-wold  UM1HG009443        fastq       reads
# 2          30471929  barbara-wold  UM1HG009443        fastq       reads
# 3          29889475  barbara-wold  UM1HG009443        fastq       reads
# 4          86476491  barbara-wold  UM1HG009443        fastq       reads
#
#            platform library_id:skip                     replicate
# 0  encode:HiSeq2500        17327_A1   barbara-wold:17327_A1_b1_t1
# 1  encode:HiSeq2500        17327_A1   barbara-wold:17327_A1_b1_t1
# 2  encode:HiSeq2500       17327_A10  barbara-wold:17327_A10_b1_t1
# 3  encode:HiSeq2500       17327_A10  barbara-wold:17327_A10_b1_t1
# 4  encode:HiSeq2500       17327_A11  barbara-wold:17327_A11_b1_t1
#
# [5 rows x 23 columns]

# %%
libraries = models.load_library_tables(['all_analysis_vdir/library-passing.tsv'])
experiments = models.load_experiments(['all_analysis_vdir/experiment_vdir.tsv'])
# Out:
# Unrecognized columns present. Is this intended?: analysis_name

# %%
import dask
from dask.distributed import Client
import hashlib

def import_htsw():
    HTSW = os.path.expanduser('~diane/proj/htsworkflow')
    if HTSW not in sys.path:
        sys.path.append(HTSW)
    from htsworkflow.submission.encoded import ENCODED
    from htsworkflow.submission.fastqname import FastqName
    
def get_md5sum(filename):
    block = 4096
    count = 10
    md5 = hashlib.md5()
    with open(filename, 'rb') as stream:
        while True:
            buffer = stream.read(block * count)
            if len(buffer) == 0:
                break
            md5.update(buffer)
    return (filename, md5.hexdigest())


c = Client('127.0.0.1:8786')
#c = Client()

c.run(import_htsw)

def create_md5s(libraries):
    files = []
    for i, lib in libraries.iterrows():
        files.append(models.find_library_bam_file(lib, 'genome'))
        files.append(models.find_library_bam_file(lib, 'transcriptome'))
        files.append(find_rsem(lib, 'genome'))
        files.append(find_rsem(lib, 'transcriptome'))
        files.append(find_bigwig(lib, 'uniq'))
        files.append(find_bigwig(lib, 'all'))
         
    md5s = c.map(get_md5sum, files)
    md5_values = c.gather(md5s)
    return md5_values

processed_md5_filename = 'all_analysis_vdir/processed_md5s.csv'
if not os.path.exists(processed_md5_filename):
    md5_values = create_md5s(libraries)
    pandas.DataFrame(md5_values, columns=['filename', 'md5sum']).to_csv(processed_md5_filename)
else:
    md5_values = pandas.read_csv(processed_md5_filename).set_index('filename')['md5sum'].to_dict()
print('md5s calculated', len(md5_values))
# Out:
# md5s calculated 6222

# %%
l = libraries.iloc[0]

# %%
assert l.stranded == 'unstranded'

# %%
metadata[metadata['library'] == 'barbara-wold:{}'.format(l.name)]
# Out:
#                                      uuid  \
# 818  51e96f22-533a-4550-9311-2d90cc98f888
# 819  51e96f22-533a-4550-9311-2d90cc98f888
#
#                                           experiment  \
# 818  barbara-wold:c1_e11.5_mouse_limb_run10_19906_A5
# 819  barbara-wold:c1_e11.5_mouse_limb_run10_19906_A5
#
#      biological_replicate_number:integer  technical_replicate_number:integer  \
# 818                                    1                                   1
# 819                                    1                                   1
#
#                    library                aliases:array    accession  \
# 818  barbara-wold:19906_A5  barbara-wold:19906_A5_b1_t1  ENCSR741DDM
# 819  barbara-wold:19906_A5  barbara-wold:19906_A5_b1_t1  ENCSR741DDM
#
#                                   aliases:experiment file_accession  \
# 818  barbara-wold:c1_e11.5_mouse_limb_run10_19906_A5    ENCFF531EHX
# 819  barbara-wold:c1_e11.5_mouse_limb_run10_19906_A5    ENCFF506KKD
#
#                                              dataset  \
# 818  barbara-wold:c1_e11.5_mouse_limb_run10_19906_A5
# 819  barbara-wold:c1_e11.5_mouse_limb_run10_19906_A5
#
#                 ...               \
# 818             ...
# 819             ...
#
#                                  flowcell_details:json read_length:integer  \
# 818  [{"machine": "http://jumpgate.caltech.edu/sequ...                  50
# 819  [{"machine": "http://jumpgate.caltech.edu/sequ...                  50
#
#     file_size:integer           lab        award  file_format output_type  \
# 818          27870489  barbara-wold  UM1HG009443        fastq       reads
# 819          27759563  barbara-wold  UM1HG009443        fastq       reads
#
#              platform library_id:skip                    replicate
# 818  encode:HiSeq2500        19906_A5  barbara-wold:19906_A5_b1_t1
# 819  encode:HiSeq2500        19906_A5  barbara-wold:19906_A5_b1_t1
#
# [2 rows x 23 columns]

# %%
fastq_rows = metadata[metadata['library'] == 'barbara-wold:{}'.format(l.name)]
'/experiment/{}/'.format(fastq_rows.loc[fastq_rows.first_valid_index()]['accession'])
# Out:
# '/experiment/ENCSR741DDM/'

# %%
models.find_library_bam_file(l)
# Out:
# '/woldlab/castor/home/sau/flowcells/H7CNTBCX2/19906_A5/19906_A5-mm10-M4-male_genome.bam'

# %%
models.find_library_bam_file(l, 'transcriptome')
# Out:
# '/woldlab/castor/home/sau/flowcells/H7CNTBCX2/19906_A5/19906_A5-mm10-M4-male_anno.bam'

# %%
l
# Out:
# analysis_dir        /woldlab/castor/home/sau/flowcells/H7CNTBCX2/1...
# genome                                                           mm10
# annotation                                                         M4
# sex                                                              male
# read_1                                            19906_A5_*.fastq.gz
# reference_prefix                                                    -
# analysis_name                                                19906_A5
# stranded                                                   unstranded
# Name: 19906_A5, dtype: object

# %%
def guess_flowcell(library):
    sau = os.path.expanduser('~sau/flowcells/')
    analysis_dir = library.analysis_dir.replace(sau, '')
    flowcell, subdir = os.path.split(analysis_dir)
    return flowcell
    
guess_flowcell(l)
# Out:
# 'H7CNTBCX2'

# %%
def find_bigwig(library, track_type, analysis_root=None):
    assert library.stranded == 'unstranded'

    paths = [library.analysis_dir, os.path.expanduser('~sau/public_html/{}'.format(guess_flowcell(library)))]
    filename = library.analysis_name + '-' + models.genome_name_from_library(library) + "_" + track_type + '.bw'
    for p in paths:
        pathname = os.path.join(p, filename)
        if os.path.exists(pathname):
            return pathname
            break

# %%
find_bigwig(l, 'uniq')
# Out:
# '/woldlab/castor/home/sau/public_html/H7CNTBCX2/19906_A5-mm10-M4-male_uniq.bw'

# %%
def find_rsem(library, reference_type='genome', analysis_root=None):
    assert reference_type in ['genome', 'transcriptome'], "reference_type is either genome or transcriptome"
    if reference_type == 'genome':
        suffix = "_anno_rsem.genes.results"
    else: # reference_type == 'transcriptome':
        suffix = "_anno_rsem.isoforms.results"

    filename = library.analysis_name + '-' + models.genome_name_from_library(library) + suffix
    pathname = os.path.join(library.analysis_dir, filename)
    assert os.path.exists(pathname)
    return pathname

# %%
find_rsem(l, reference_type='transcriptome')
# Out:
# '/woldlab/castor/home/sau/flowcells/H7CNTBCX2/19906_A5/19906_A5-mm10-M4-male_anno_rsem.isoforms.results'

# %%
def create_analysis_step_run(server, validator, step, run, dry_run):
    obj = {
        'aliases': [run],
        'analysis_step_version': step,
        'status': 'in progress',
    }
    collection = '/analysis-step-runs/'
    validator.validate(obj, collection)
    #if not dry_run:
    #    return server.post_json(collection, obj)
    #else:
    return obj

def create_analysis_step_runs(server, validator, dry_run=True):
    steps = [
        'encode:wold-bulk-rnaseq-alignment-step-v1',
        'encode:wold-bulk-rnaseq-signal-generation-step-v1',
        'encode:wold-bulk-rnaseq-quantification-step-v1',
    ]
    for step in steps:
        run = step.replace('-step', '-run').replace('encode:', 'barbara-wold:')
        print('run', run)
        need_to_create = False
        try:
            obj = server.get_json(run)
            pprint(obj)
        except encoded.HTTPError as e:
            if e.response.status_code == 404:
                print(f'Need to create {run}')
                need_to_create = True
        if need_to_create:
            pprint(create_analysis_step_run(server, validator, step, run, dry_run))


create_analysis_step_runs(server, validator, dry_run=True)
# Out:
# run barbara-wold:wold-bulk-rnaseq-alignment-run-v1
# {'@context': '/terms/',
#  '@id': '/analysis-step-runs/ecd38dae-7937-4865-8f82-0a3829f1b249/',
#  '@type': ['AnalysisStepRun', 'Item'],
#  'aliases': ['barbara-wold:wold-bulk-rnaseq-alignment-run-v1'],
#  'analysis_step_version': {'@id': '/analysis-step-versions/wold-bulk-rnaseq-star-alignment-step-v-1-0/',
#                            '@type': ['AnalysisStepVersion', 'Item'],
#                            'aliases': ['encode:wold-bulk-rnaseq-alignment-step-v1'],
#                            'analysis_step': {'@id': '/analysis-steps/wold-bulk-rnaseq-star-alignment-step-v-1/',
#                                              '@type': ['AnalysisStep', 'Item'],
#                                              'aliases': ['encode:wold-bulk-rnaseq-alignment-step'],
#                                              'analysis_step_types': ['alignment',
#                                                                      'QA '
#                                                                      'calculation'],
#                                              'current_version': '/analysis-step-versions/wold-bulk-rnaseq-star-alignment-step-v-1-0/',
#                                              'date_created': '2020-01-09T16:12:47.554959+00:00',
#                                              'documents': [],
#                                              'input_file_types': ['reads',
#                                                                   'genome '
#                                                                   'index'],
#                                              'major_version': 1,
#                                              'name': 'wold-bulk-rnaseq-star-alignment-step-v-1',
#                                              'output_file_types': ['alignments',
#                                                                    'transcriptome '
#                                                                    'alignments'],
#                                              'pipelines': ['/pipelines/ENCPL302UGO/'],
#                                              'schema_version': '8',
#                                              'status': 'released',
#                                              'step_label': 'wold-bulk-rnaseq-star-alignment-step',
#                                              'submitted_by': '/users/64974e05-12df-4733-ae90-b402298b142e/',
#                                              'title': 'Wold Bulk RNA-Seq '
#                                                       'Alignment Step',
#                                              'uuid': '63f0c8b2-bb83-4786-a1bc-bb2caf72b8b8',
#                                              'versions': ['/analysis-step-versions/wold-bulk-rnaseq-star-alignment-step-v-1-0/']},
#                            'date_created': '2020-01-10T01:28:08.636931+00:00',
#                            'minor_version': 0,
#                            'name': 'wold-bulk-rnaseq-star-alignment-step-v-1-0',
#                            'schema_version': '4',
#                            'software_versions': ['/software-versions/ef94cd69-7316-480d-b785-e1cb36d1ea97/',
#                                                  '/software-versions/ff27407c-47d2-4d4a-85fe-f64e25a43ce2/'],
#                            'status': 'released',
#                            'submitted_by': '/users/64974e05-12df-4733-ae90-b402298b142e/',
#                            'uuid': 'bb6f5119-290f-48b4-add4-a2b252aa4f6d'},
#  'audit': {},
#  'date_created': '2020-01-13T16:39:19.471115+00:00',
#  'schema_version': '5',
#  'status': 'released',
#  'submitted_by': '/users/64974e05-12df-4733-ae90-b402298b142e/',
#  'uuid': 'ecd38dae-7937-4865-8f82-0a3829f1b249'}
# run barbara-wold:wold-bulk-rnaseq-signal-generation-run-v1
# {'@context': '/terms/',
#  '@id': '/analysis-step-runs/6e5ac5c3-b9fd-4b10-a13e-47d4ab2e6bf8/',
#  '@type': ['AnalysisStepRun', 'Item'],
#  'aliases': ['barbara-wold:wold-bulk-rnaseq-signal-generation-run-v1'],
#  'analysis_step_version': {'@id': '/analysis-step-versions/wold-bulk-rnaseq-star-signal-generation-step-v-1-0/',
#                            '@type': ['AnalysisStepVersion', 'Item'],
#                            'aliases': ['encode:wold-bulk-rnaseq-signal-generation-step-v1'],
#                            'analysis_step': {'@id': '/analysis-steps/wold-bulk-rnaseq-star-signal-generation-step-v-1/',
#                                              '@type': ['AnalysisStep', 'Item'],
#                                              'aliases': ['encode:wold-bulk-rnaseq-signal-generation-step'],
#                                              'analysis_step_types': ['signal '
#                                                                      'generation',
#                                                                      'file '
#                                                                      'format '
#                                                                      'conversion'],
#                                              'current_version': '/analysis-step-versions/wold-bulk-rnaseq-star-signal-generation-step-v-1-3/',
#                                              'date_created': '2020-01-09T16:15:01.798522+00:00',
#                                              'documents': [],
#                                              'input_file_types': ['alignments'],
#                                              'major_version': 1,
#                                              'name': 'wold-bulk-rnaseq-star-signal-generation-step-v-1',
#                                              'output_file_types': ['signal of '
#                                                                    'all reads',
#                                                                    'signal of '
#                                                                    'unique '
#                                                                    'reads'],
#                                              'parents': ['/analysis-steps/wold-bulk-rnaseq-star-alignment-step-v-1/'],
#                                              'pipelines': ['/pipelines/ENCPL302UGO/'],
#                                              'schema_version': '8',
#                                              'status': 'released',
#                                              'step_label': 'wold-bulk-rnaseq-star-signal-generation-step',
#                                              'submitted_by': '/users/64974e05-12df-4733-ae90-b402298b142e/',
#                                              'title': 'Wold Bulk RNA-seq '
#                                                       'Signal Generation Step',
#                                              'uuid': 'c053ba7e-947b-4e12-9c44-581423f26a42',
#                                              'versions': ['/analysis-step-versions/wold-bulk-rnaseq-star-signal-generation-step-v-1-0/',
#                                                           '/analysis-step-versions/wold-bulk-rnaseq-star-signal-generation-step-v-1-3/']},
#                            'date_created': '2020-01-10T01:21:07.179794+00:00',
#                            'minor_version': 0,
#                            'name': 'wold-bulk-rnaseq-star-signal-generation-step-v-1-0',
#                            'schema_version': '4',
#                            'software_versions': ['/software-versions/32963773-e32a-48b6-8a78-59733d2f2333/'],
#                            'status': 'released',
#                            'submitted_by': '/users/64974e05-12df-4733-ae90-b402298b142e/',
#                            'uuid': '943f5d1a-382d-42c2-b47f-975c13639bab'},
#  'audit': {},
#  'date_created': '2020-01-13T16:39:11.759455+00:00',
#  'schema_version': '5',
#  'status': 'released',
#  'submitted_by': '/users/64974e05-12df-4733-ae90-b402298b142e/',
#  'uuid': '6e5ac5c3-b9fd-4b10-a13e-47d4ab2e6bf8'}
# run barbara-wold:wold-bulk-rnaseq-quantification-run-v1
# {'@context': '/terms/',
#  '@id': '/analysis-step-runs/76310d0b-df30-45e6-bd5f-44c07e2d219e/',
#  '@type': ['AnalysisStepRun', 'Item'],
#  'aliases': ['encode:wold-bulk-rnaseq-quantification-step-v1-run1',
#              'barbara-wold:wold-bulk-rnaseq-quantification-run-v1'],
#  'analysis_step_version': {'@id': '/analysis-step-versions/wold-bulk-rnaseq-rsem-quantification-step-v-1-0/',
#                            '@type': ['AnalysisStepVersion', 'Item'],
#                            'aliases': ['encode:wold-bulk-rnaseq-quantification-step-v1'],
#                            'analysis_step': {'@id': '/analysis-steps/wold-bulk-rnaseq-rsem-quantification-step-v-1/',
#                                              '@type': ['AnalysisStep', 'Item'],
#                                              'aliases': ['encode:wold-bulk-rnaseq-quantification-step'],
#                                              'analysis_step_types': ['quantification'],
#                                              'current_version': '/analysis-step-versions/wold-bulk-rnaseq-rsem-quantification-step-v-1-0/',
#                                              'date_created': '2020-01-09T16:17:01.232605+00:00',
#                                              'documents': [],
#                                              'input_file_types': ['transcriptome '
#                                                                   'alignments',
#                                                                   'genome '
#                                                                   'index'],
#                                              'major_version': 1,
#                                              'name': 'wold-bulk-rnaseq-rsem-quantification-step-v-1',
#                                              'output_file_types': ['gene '
#                                                                    'quantifications',
#                                                                    'transcript '
#                                                                    'quantifications'],
#                                              'parents': ['/analysis-steps/wold-bulk-rnaseq-star-alignment-step-v-1/'],
#                                              'pipelines': ['/pipelines/ENCPL302UGO/'],
#                                              'schema_version': '8',
#                                              'status': 'released',
#                                              'step_label': 'wold-bulk-rnaseq-rsem-quantification-step',
#                                              'submitted_by': '/users/64974e05-12df-4733-ae90-b402298b142e/',
#                                              'title': 'Wold Bulk RNA-seq '
#                                                       'Quantification Step',
#                                              'uuid': '1917f001-c7a3-47bf-854f-5f9f7922d431',
#                                              'versions': ['/analysis-step-versions/wold-bulk-rnaseq-rsem-quantification-step-v-1-0/']},
#                            'date_created': '2020-01-09T17:50:50.212142+00:00',
#                            'minor_version': 0,
#                            'name': 'wold-bulk-rnaseq-rsem-quantification-step-v-1-0',
#                            'schema_version': '4',
#                            'software_versions': ['/software-versions/08a31dbd-e957-4004-bf0c-8506388d9fed/'],
#                            'status': 'released',
#                            'submitted_by': '/users/64974e05-12df-4733-ae90-b402298b142e/',
#                            'uuid': '96ca39bc-0033-488e-ae7d-e12478e7a069'},
#  'audit': {},
#  'date_created': '2020-01-10T01:19:37.440499+00:00',
#  'schema_version': '5',
#  'status': 'released',
#  'submitted_by': '/users/64974e05-12df-4733-ae90-b402298b142e/',
#  'uuid': '76310d0b-df30-45e6-bd5f-44c07e2d219e'}

# %%
def sanitize_submitted_filename(filename):
    if filename.startswith('/'):
        paths = [
            os.path.expanduser('~sau/flowcells/'),
            os.path.expanduser('~diane/proj/flowcells/'),
        ]
        for p in paths:
            if filename.startswith(p):
                return filename.replace(p, '')
        else:
            raise ValueError("Unrecognized filename {}".format(filename))
    else:
        return filename

# %%
sanitize_submitted_filename(find_rsem(l))
# Out:
# 'H7CNTBCX2/19906_A5/19906_A5-mm10-M4-male_anno_rsem.genes.results'

# %%
def generate_bam_object(library, metadata, md5_cache, reference_type='genome'):
    validate_reference_type(reference_type)
    if reference_type == 'genome':
        output_type = 'alignments'
    else:
        output_type = 'transcriptome alignments'
    suffix_map = {
        'genome': 'genome',
        'transcriptome': 'anno',
    }
        
    alignment = models.find_library_bam_file(library, reference_type)
    star_index = '/file/ENCFF483PAE/'
    
    fastq_rows = metadata[metadata['library'] == 'barbara-wold:{}'.format(library.name)]
    dataset = '/experiments/{}/'.format(
        fastq_rows.loc[fastq_rows.first_valid_index()]['accession']
    )
    derived_from = ['/file/{}/'.format(x) for x in fastq_rows['file_accession']]
    derived_from.append(star_index)

    triplet = models.genome_name_from_library(library)
    suffix = suffix_map[reference_type]
    bam_alias = f'barbara-wold:{library.analysis_name}-{triplet}_{suffix}.bam'

    obj = {
        #'@type': ['File'],
        'aliases': [bam_alias],
        'dataset': dataset,
        'file_format': 'bam',
        #'output_category': 'alignment',
        'output_type': output_type,
        'assembly': 'mm10-minimal',
        'genome_annotation': library.annotation,
        'step_run': '/analysis-step-runs/ecd38dae-7937-4865-8f82-0a3829f1b249/',
        'derived_from': derived_from,
        'award': 'UM1HG009443',
        'lab': '/labs/barbara-wold/',
        'md5sum': md5_values[alignment],
        'file_size': os.stat(alignment).st_size,
        'submitted_file_name': alignment,
    }
    return obj

# %%
genome_bam = generate_bam_object(l, metadata, md5_values, 'genome')
validator.validate(genome_bam, 'File')
genome_bam
# Out:
# {'aliases': ['barbara-wold:19906_A5-mm10-M4-male_genome.bam'],
#  'dataset': '/experiments/ENCSR741DDM/',
#  'file_format': 'bam',
#  'output_type': 'alignments',
#  'assembly': 'mm10-minimal',
#  'genome_annotation': 'M4',
#  'step_run': '/analysis-step-runs/ecd38dae-7937-4865-8f82-0a3829f1b249/',
#  'derived_from': ['/file/ENCFF531EHX/',
#   '/file/ENCFF506KKD/',
#   '/file/ENCFF483PAE/'],
#  'award': 'UM1HG009443',
#  'lab': '/labs/barbara-wold/',
#  'md5sum': '225757e3e69fa8bf0412cc71c708dd3d',
#  'file_size': 77642556,
#  'submitted_file_name': '/woldlab/castor/home/sau/flowcells/H7CNTBCX2/19906_A5/19906_A5-mm10-M4-male_genome.bam'}

# %%
transcriptome_bam = generate_bam_object(l, metadata, md5_values, 'transcriptome')
validator.validate(transcriptome_bam, 'File')
transcriptome_bam
# Out:
# {'aliases': ['barbara-wold:19906_A5-mm10-M4-male_anno.bam'],
#  'dataset': '/experiments/ENCSR741DDM/',
#  'file_format': 'bam',
#  'output_type': 'transcriptome alignments',
#  'assembly': 'mm10-minimal',
#  'genome_annotation': 'M4',
#  'step_run': '/analysis-step-runs/ecd38dae-7937-4865-8f82-0a3829f1b249/',
#  'derived_from': ['/file/ENCFF531EHX/',
#   '/file/ENCFF506KKD/',
#   '/file/ENCFF483PAE/'],
#  'award': 'UM1HG009443',
#  'lab': '/labs/barbara-wold/',
#  'md5sum': '1da6f195906220e222191910c1b3121f',
#  'file_size': 71730686,
#  'submitted_file_name': '/woldlab/castor/home/sau/flowcells/H7CNTBCX2/19906_A5/19906_A5-mm10-M4-male_anno.bam'}

# %%
hashlib.md5(b'').hexdigest()
# Out:
# 'd41d8cd98f00b204e9800998ecf8427e'

# %% [markdown]
# Alignment analysis_step_run: /analysis-step-runs/ecd38dae-7937-4865-8f82-0a3829f1b249/
#
# Signal Generation analysis_step_run: /analysis-step-runs/6e5ac5c3-b9fd-4b10-a13e-47d4ab2e6bf8/
#
# Quantification analysis_step_run: /analysis-step-runs/76310d0b-df30-45e6-bd5f-44c07e2d219e/

# %%
def get_attachment(filename, mime_type):
    with open(filename, 'rb') as instream:
        contents = instream.read()
        print(type(contents))
        payload = "data:{};base64,{}".format(
            mime_type, 
            b64encode(contents).decode("ascii"))
        obj = {
            "type": mime_type,
            "download": filename.split("/")[-1],
            "href": payload,
            "size": len(contents),
            "md5sum": hashlib.md5(contents).hexdigest(),
        }
        return obj

def generate_flagstat_object(library, reference_type):
    suffix_map = {
        'genome': 'genome',
        'transcriptome': 'anno',
    }
    triplet = models.genome_name_from_library(library)
    suffix = suffix_map[reference_type]
    bam_alias = f'barbara-wold:{library.analysis_name}-{triplet}_{suffix}.bam'
    flagstat_filename = f'{library.analysis_name}-{triplet}_{suffix}.flagstat'
    flagstat_pathname = os.path.join('all_analysis_vdir', flagstat_filename)
    flagstat = models.load_flagstat(flagstat_pathname)
    flagstat['@type'] = ['SamtoolsFlagstatsQualityMetric', 'QualityMetric', 'Item']
    flagstat['quality_metric_of'] = [bam_alias]
    flagstat['step_run'] = '/analysis-step-runs/ecd38dae-7937-4865-8f82-0a3829f1b249/'
    flagstat['attachment'] = get_attachment(flagstat_pathname, 'text/plain')
    flagstat['award'] = 'UM1HG009443'
    flagstat['lab'] = '/labs/barbara-wold/'
    return flagstat

# %%
genome_flagstat = generate_flagstat_object(l, 'genome')
pprint(genome_flagstat)
validator.validate(genome_flagstat, 'SamtoolsFlagstatsQualityMetric')
# Out:
# <class 'bytes'>
# {'@type': ['SamtoolsFlagstatsQualityMetric', 'QualityMetric', 'Item'],
#  'attachment': {'download': '19906_A5-mm10-M4-male_genome.flagstat',
#                 'href': 'data:text/plain;base64,...',
#                 'md5sum': '3874fbcd1575b784f6992b31cee99e8b',
#                 'size': 407,
#                 'type': 'text/plain'},
#  'award': 'UM1HG009443',
#  'duplicates': 0,
#  'duplicates_qc_failed': 0,
#  'lab': '/labs/barbara-wold/',
#  'mapped': 1635004,
#  'mapped_pct': '97.66',
#  'mapped_qc_failed': 89807,
#  'quality_metric_of': ['barbara-wold:19906_A5-mm10-M4-male_genome.bam'],
#  'step_run': '/analysis-step-runs/ecd38dae-7937-4865-8f82-0a3829f1b249/',
#  'total': 1674256,
#  'total_qc_failed': 101288}

# %%
def generate_bigwig_object(library, bam, md5_cache, bigwig_type='uniq'):
    if bigwig_type == 'uniq':
        output_type = 'signal of unique reads'
    elif bigwig_type == 'all':
        output_type = 'signal of all reads'
    else:
        raise NotImplemented('Only unstranded implemented')
    
    assert bam['output_type'] == 'alignments'
    derived_from = [bam['aliases'][0]]
    bigwig = find_bigwig(library, bigwig_type)
    
    obj = {
        #'@type': ['File'],
        'aliases': [],
        'dataset': bam['dataset'],
        'file_format': 'bigWig',
        #'output_category': 'signal',
        'output_type': output_type,
        'assembly': 'mm10-minimal',
        'genome_annotation': library.annotation,
        'step_run': '/analysis-step-runs/6e5ac5c3-b9fd-4b10-a13e-47d4ab2e6bf8/',
        'derived_from': derived_from,
        'award': 'UM1HG009443',
        'lab': '/labs/barbara-wold/',
        'md5sum': md5_cache[bigwig],
        'file_size': os.stat(bigwig).st_size,
        'submitted_file_name': bigwig,
    }
    return obj

# %%
uniq_bigwig = generate_bigwig_object(l, genome_bam, md5_values, 'uniq')
validator.validate(uniq_bigwig, 'File')
uniq_bigwig
# Out:
# {'aliases': [],
#  'dataset': '/experiments/ENCSR741DDM/',
#  'file_format': 'bigWig',
#  'output_type': 'signal of unique reads',
#  'assembly': 'mm10-minimal',
#  'genome_annotation': 'M4',
#  'step_run': '/analysis-step-runs/6e5ac5c3-b9fd-4b10-a13e-47d4ab2e6bf8/',
#  'derived_from': ['barbara-wold:19906_A5-mm10-M4-male_genome.bam'],
#  'award': 'UM1HG009443',
#  'lab': '/labs/barbara-wold/',
#  'md5sum': '07cd28255fed50d810465402701034a8',
#  'file_size': 7017411,
#  'submitted_file_name': '/woldlab/castor/home/sau/public_html/H7CNTBCX2/19906_A5-mm10-M4-male_uniq.bw'}

# %%
all_bigwig = generate_bigwig_object(l, genome_bam, md5_values, 'all')
validator.validate(all_bigwig, 'File')
all_bigwig
# Out:
# {'aliases': [],
#  'dataset': '/experiments/ENCSR741DDM/',
#  'file_format': 'bigWig',
#  'output_type': 'signal of all reads',
#  'assembly': 'mm10-minimal',
#  'genome_annotation': 'M4',
#  'step_run': '/analysis-step-runs/6e5ac5c3-b9fd-4b10-a13e-47d4ab2e6bf8/',
#  'derived_from': ['barbara-wold:19906_A5-mm10-M4-male_genome.bam'],
#  'award': 'UM1HG009443',
#  'lab': '/labs/barbara-wold/',
#  'md5sum': 'f040d64033fea22bc7f27e6abe0fbcf3',
#  'file_size': 12492215,
#  'submitted_file_name': '/woldlab/castor/home/sau/public_html/H7CNTBCX2/19906_A5-mm10-M4-male_all.bw'}

# %%
def generate_rsem_object(library, bam, md5_cache, reference_type='genome'):
    validate_reference_type(reference_type)
    if reference_type == 'genome':
        output_type = 'gene quantifications'
    else:
        output_type = 'transcript quantifications'
    
    assert bam['output_type'] == 'transcriptome alignments'
    derived_from = [bam['aliases'][0], '/files/ENCFF064YNQ/']
    rsem = find_rsem(library, reference_type)
    
    obj = {
        #'@type': ['File'],
        'aliases': [],
        'dataset': bam['dataset'],
        'file_format': 'tsv',
        #'output_category': 'quantification',
        'output_type': output_type,
        'assembly': 'mm10-minimal',  #library.genome,
        'genome_annotation': library.annotation,
        'step_run': '/analysis-step-runs/76310d0b-df30-45e6-bd5f-44c07e2d219e/',
        'derived_from': derived_from,
        'award': 'UM1HG009443',
        'lab': '/labs/barbara-wold/',
        'md5sum': md5_cache[rsem],
        'file_size': os.stat(rsem).st_size,
        'submitted_file_name': rsem,
    }
    return obj

# %%
genome_rsem = generate_rsem_object(l, transcriptome_bam, md5_values, 'genome')
validator.validate(genome_rsem, 'File')
genome_rsem
# Out:
# {'aliases': [],
#  'dataset': '/experiments/ENCSR741DDM/',
#  'file_format': 'tsv',
#  'output_type': 'gene quantifications',
#  'assembly': 'mm10-minimal',
#  'genome_annotation': 'M4',
#  'step_run': '/analysis-step-runs/76310d0b-df30-45e6-bd5f-44c07e2d219e/',
#  'derived_from': ['barbara-wold:19906_A5-mm10-M4-male_anno.bam',
#   '/files/ENCFF064YNQ/'],
#  'award': 'UM1HG009443',
#  'lab': '/labs/barbara-wold/',
#  'md5sum': '362e256e66652ebedaabd9c75928f3aa',
#  'file_size': 9542941,
#  'submitted_file_name': '/woldlab/castor/home/sau/flowcells/H7CNTBCX2/19906_A5/19906_A5-mm10-M4-male_anno_rsem.genes.results'}

# %%
transcriptome_rsem = generate_rsem_object(l, transcriptome_bam, md5_values, 'transcriptome')
validator.validate(transcriptome_rsem, 'File')
transcriptome_rsem
# Out:
# {'aliases': [],
#  'dataset': '/experiments/ENCSR741DDM/',
#  'file_format': 'tsv',
#  'output_type': 'transcript quantifications',
#  'assembly': 'mm10-minimal',
#  'genome_annotation': 'M4',
#  'step_run': '/analysis-step-runs/76310d0b-df30-45e6-bd5f-44c07e2d219e/',
#  'derived_from': ['barbara-wold:19906_A5-mm10-M4-male_anno.bam',
#   '/files/ENCFF064YNQ/'],
#  'award': 'UM1HG009443',
#  'lab': '/labs/barbara-wold/',
#  'md5sum': 'e92a671bda0bfd524666652f2a99c43a',
#  'file_size': 17413669,
#  'submitted_file_name': '/woldlab/castor/home/sau/flowcells/H7CNTBCX2/19906_A5/19906_A5-mm10-M4-male_anno_rsem.isoforms.results'}

# %%
pandas.DataFrame([
    genome_bam,
    transcriptome_bam,
    uniq_bigwig,
    all_bigwig,
    genome_rsem,
    transcriptome_rsem,
]).rename({
    'aliases': 'aliases:array',
    'derived_from': 'derived_from:array',
    'quality_metrics': 'quality_metrics:json'
    
})
# Out:
#                                            aliases      assembly        award  \
# 0  [barbara-wold:19906_A5-mm10-M4-male_genome.bam]  mm10-minimal  UM1HG009443
# 1    [barbara-wold:19906_A5-mm10-M4-male_anno.bam]  mm10-minimal  UM1HG009443
# 2                                               []  mm10-minimal  UM1HG009443
# 3                                               []  mm10-minimal  UM1HG009443
# 4                                               []  mm10-minimal  UM1HG009443
# 5                                               []  mm10-minimal  UM1HG009443
#
#                      dataset  \
# 0  /experiments/ENCSR741DDM/
# 1  /experiments/ENCSR741DDM/
# 2  /experiments/ENCSR741DDM/
# 3  /experiments/ENCSR741DDM/
# 4  /experiments/ENCSR741DDM/
# 5  /experiments/ENCSR741DDM/
#
#                                         derived_from file_format  file_size  \
# 0  [/file/ENCFF531EHX/, /file/ENCFF506KKD/, /file...         bam   77642556
# 1  [/file/ENCFF531EHX/, /file/ENCFF506KKD/, /file...         bam   71730686
# 2    [barbara-wold:19906_A5-mm10-M4-male_genome.bam]      bigWig    7017411
# 3    [barbara-wold:19906_A5-mm10-M4-male_genome.bam]      bigWig   12492215
# 4  [barbara-wold:19906_A5-mm10-M4-male_anno.bam, ...         tsv    9542941
# 5  [barbara-wold:19906_A5-mm10-M4-male_anno.bam, ...         tsv   17413669
#
#   genome_annotation                  lab                            md5sum  \
# 0                M4  /labs/barbara-wold/  225757e3e69fa8bf0412cc71c708dd3d
# 1                M4  /labs/barbara-wold/  1da6f195906220e222191910c1b3121f
# 2                M4  /labs/barbara-wold/  07cd28255fed50d810465402701034a8
# 3                M4  /labs/barbara-wold/  f040d64033fea22bc7f27e6abe0fbcf3
# 4                M4  /labs/barbara-wold/  362e256e66652ebedaabd9c75928f3aa
# 5                M4  /labs/barbara-wold/  e92a671bda0bfd524666652f2a99c43a
#
#                   output_type  \
# 0                  alignments
# 1    transcriptome alignments
# 2      signal of unique reads
# 3         signal of all reads
# 4        gene quantifications
# 5  transcript quantifications
#
#                                             step_run  \
# 0  /analysis-step-runs/ecd38dae-7937-4865-8f82-0a...
# 1  /analysis-step-runs/ecd38dae-7937-4865-8f82-0a...
# 2  /analysis-step-runs/6e5ac5c3-b9fd-4b10-a13e-47...
# 3  /analysis-step-runs/6e5ac5c3-b9fd-4b10-a13e-47...
# 4  /analysis-step-runs/76310d0b-df30-45e6-bd5f-44...
# 5  /analysis-step-runs/76310d0b-df30-45e6-bd5f-44...
#
#                                  submitted_file_name
# 0  /woldlab/castor/home/sau/flowcells/H7CNTBCX2/1...
# 1  /woldlab/castor/home/sau/flowcells/H7CNTBCX2/1...
# 2  /woldlab/castor/home/sau/public_html/H7CNTBCX2...
# 3  /woldlab/castor/home/sau/public_html/H7CNTBCX2...
# 4  /woldlab/castor/home/sau/flowcells/H7CNTBCX2/1...
# 5  /woldlab/castor/home/sau/flowcells/H7CNTBCX2/1...

# %%
validator = encoded.DCCValidator(server)
processed_files = []
for i, lib in libraries.iterrows():
    gene_bam = generate_bam_object(lib, metadata, md5_values, 'genome')
    transcript_bam = generate_bam_object(lib, metadata, md5_values, 'transcriptome')
    all_bigwig = generate_bigwig_object(lib, gene_bam, md5_values, 'all')
    uniq_bigwig = generate_bigwig_object(lib, gene_bam, md5_values, 'uniq')
    gene_rsem = generate_rsem_object(lib, transcript_bam, md5_values, 'genome')
    transcript_rsem = generate_rsem_object(lib, transcript_bam, md5_values, 'transcriptome')
    for f in [gene_bam, transcript_bam, all_bigwig, uniq_bigwig, gene_rsem, transcript_rsem]:
        validator.validate(f, 'File')
        processed_files.append(f)

# %%
processed_files_df = pandas.DataFrame(processed_files).rename({
    'aliases': 'aliases:array',
    'derived_from': 'derived_from:array',
    'quality_metrics': 'quality_metrics:json',
    'file_size': 'file_size:integer',
}, axis=1)
processed_files_df.insert(0, 'accession', numpy.nan)
processed_files_df.insert(0, 'uuid', numpy.nan)

# %%
processed_files_df['aliases:array'] = processed_files_df['aliases:array'].apply(lambda x: ','.join(x))
processed_files_df['derived_from:array'] = processed_files_df['derived_from:array'].apply(lambda x: ','.join(x))

# %%
processed_files_df.head()
# Out:
#    uuid  accession                                  aliases:array  \
# 0   NaN        NaN  barbara-wold:19906_A5-mm10-M4-male_genome.bam
# 1   NaN        NaN    barbara-wold:19906_A5-mm10-M4-male_anno.bam
# 2   NaN        NaN
# 3   NaN        NaN
# 4   NaN        NaN
#
#        assembly        award                    dataset  \
# 0  mm10-minimal  UM1HG009443  /experiments/ENCSR741DDM/
# 1  mm10-minimal  UM1HG009443  /experiments/ENCSR741DDM/
# 2  mm10-minimal  UM1HG009443  /experiments/ENCSR741DDM/
# 3  mm10-minimal  UM1HG009443  /experiments/ENCSR741DDM/
# 4  mm10-minimal  UM1HG009443  /experiments/ENCSR741DDM/
#
#                                   derived_from:array file_format  \
# 0  /file/ENCFF531EHX/,/file/ENCFF506KKD/,/file/EN...         bam
# 1  /file/ENCFF531EHX/,/file/ENCFF506KKD/,/file/EN...         bam
# 2      barbara-wold:19906_A5-mm10-M4-male_genome.bam      bigWig
# 3      barbara-wold:19906_A5-mm10-M4-male_genome.bam      bigWig
# 4  barbara-wold:19906_A5-mm10-M4-male_anno.bam,/f...         tsv
#
#    file_size:integer genome_annotation                  lab  \
# 0           77642556                M4  /labs/barbara-wold/
# 1           71730686                M4  /labs/barbara-wold/
# 2           12492215                M4  /labs/barbara-wold/
# 3            7017411                M4  /labs/barbara-wold/
# 4            9542941                M4  /labs/barbara-wold/
#
#                              md5sum               output_type  \
# 0  225757e3e69fa8bf0412cc71c708dd3d                alignments
# 1  1da6f195906220e222191910c1b3121f  transcriptome alignments
# 2  f040d64033fea22bc7f27e6abe0fbcf3       signal of all reads
# 3  07cd28255fed50d810465402701034a8    signal of unique reads
# 4  362e256e66652ebedaabd9c75928f3aa      gene quantifications
#
#                                             step_run  \
# 0  /analysis-step-runs/ecd38dae-7937-4865-8f82-0a...
# 1  /analysis-step-runs/ecd38dae-7937-4865-8f82-0a...
# 2  /analysis-step-runs/6e5ac5c3-b9fd-4b10-a13e-47...
# 3  /analysis-step-runs/6e5ac5c3-b9fd-4b10-a13e-47...
# 4  /analysis-step-runs/76310d0b-df30-45e6-bd5f-44...
#
#                                  submitted_file_name
# 0  /woldlab/castor/home/sau/flowcells/H7CNTBCX2/1...
# 1  /woldlab/castor/home/sau/flowcells/H7CNTBCX2/1...
# 2  /woldlab/castor/home/sau/public_html/H7CNTBCX2...
# 3  /woldlab/castor/home/sau/public_html/H7CNTBCX2...
# 4  /woldlab/castor/home/sau/flowcells/H7CNTBCX2/1...

# %%
processed_files_df.tail()
# Out:
#       uuid  accession                                aliases:array  \
# 6217   NaN        NaN  barbara-wold:20028_C3-mm10-M4-male_anno.bam
# 6218   NaN        NaN
# 6219   NaN        NaN
# 6220   NaN        NaN
# 6221   NaN        NaN
#
#           assembly        award                    dataset  \
# 6217  mm10-minimal  UM1HG009443  /experiments/ENCSR711YCM/
# 6218  mm10-minimal  UM1HG009443  /experiments/ENCSR711YCM/
# 6219  mm10-minimal  UM1HG009443  /experiments/ENCSR711YCM/
# 6220  mm10-minimal  UM1HG009443  /experiments/ENCSR711YCM/
# 6221  mm10-minimal  UM1HG009443  /experiments/ENCSR711YCM/
#
#                                      derived_from:array file_format  \
# 6217  /file/ENCFF074EFL/,/file/ENCFF323LPX/,/file/EN...         bam
# 6218      barbara-wold:20028_C3-mm10-M4-male_genome.bam      bigWig
# 6219      barbara-wold:20028_C3-mm10-M4-male_genome.bam      bigWig
# 6220  barbara-wold:20028_C3-mm10-M4-male_anno.bam,/f...         tsv
# 6221  barbara-wold:20028_C3-mm10-M4-male_anno.bam,/f...         tsv
#
#       file_size:integer genome_annotation                  lab  \
# 6217           87639601                M4  /labs/barbara-wold/
# 6218           13621699                M4  /labs/barbara-wold/
# 6219            8376618                M4  /labs/barbara-wold/
# 6220            9549180                M4  /labs/barbara-wold/
# 6221           17419077                M4  /labs/barbara-wold/
#
#                                 md5sum                 output_type  \
# 6217  84e3f31ff39890bf1f280afddbb984ff    transcriptome alignments
# 6218  5b41aacdd38afe5677cdd5936652bbc8         signal of all reads
# 6219  4600ddb609b805f325599fa3a14965bb      signal of unique reads
# 6220  a5e719db1ac32e3e8b5d42a45dc4d63e        gene quantifications
# 6221  46e8a0b122d16109416d7153f838af0d  transcript quantifications
#
#                                                step_run  \
# 6217  /analysis-step-runs/ecd38dae-7937-4865-8f82-0a...
# 6218  /analysis-step-runs/6e5ac5c3-b9fd-4b10-a13e-47...
# 6219  /analysis-step-runs/6e5ac5c3-b9fd-4b10-a13e-47...
# 6220  /analysis-step-runs/76310d0b-df30-45e6-bd5f-44...
# 6221  /analysis-step-runs/76310d0b-df30-45e6-bd5f-44...
#
#                                     submitted_file_name
# 6217  /woldlab/castor/home/sau/flowcells/HFNLTBCX2/2...
# 6218  /woldlab/castor/home/sau/public_html/HFNLTBCX2...
# 6219  /woldlab/castor/home/sau/public_html/HFNLTBCX2...
# 6220  /woldlab/castor/home/sau/flowcells/HFNLTBCX2/2...
# 6221  /woldlab/castor/home/sau/flowcells/HFNLTBCX2/2...

# %%
processed_files_df.shape
# Out:
# (6222, 15)

# %%
processed_files_df.to_excel('all_analysis_vdir/processed_files.xlsx', 'File', index=False)
