# %% [markdown]
# # Introduction

# %% [markdown]
# Some of the submissions are flagged as having an inconsistent biosample ontology ID, as some biosamples are tissues while the libraries are single cell.

# %%
import hashlib
import pandas
import sys
import os

# %%
HTSW=os.path.expanduser('~diane/proj/htsworkflow')
if HTSW not in sys.path:
    sys.path.append(HTSW)
from htsworkflow.submission import encoded

# %%
#server = encoded.ENCODED('www.encodeproject.org')
server = encoded.ENCODED('test.encodedcc.org')
server.load_netrc()
validator = encoded.DCCValidator(server)

# %%
uploaded_raw_sheet_filename = 'C1-mouse-forelimb-submission-201907-uploaded-production.xlsx'
uploaded = pandas.ExcelFile(uploaded_raw_sheet_filename)

# %%
submitted_experiment = uploaded.parse('Experiment')
submitted_libraries = uploaded.parse('Library')
submitted_replicates = uploaded.parse('Replicate')
submitted_files = uploaded.parse('File')

# %%
obj = server.get_json('/experiments/ENCSR869HLE/')
obj.keys()
# Out:
# dict_keys(['actions', 'audit', 'replicates', 'biosample_summary', 'internal_tags', 'accession', 'contributing_files', 'uuid', 'alternate_accessions', 'date_created', 'biosample_ontology', 'revoked_files', 'submitted_by', 'references', 'related_series', 'assay_title', '@type', 'category_slims', 'aliases', '@id', 'type_slims', 'lab', 'schema_version', 'status', 'description', 'documents', 'supersedes', 'assembly', 'superseded_by', 'award', 'original_files', '@context', 'assay_term_name', 'assay_slims', 'files', 'possible_controls', 'internal_status', 'objective_slims', 'replication_type', 'assay_term_id', 'dbxrefs', 'related_files'])

# %%
obj['biosample_ontology']['@id']
# Out:
# '/biosample-types/single_cell_UBERON_0002102/'

# %%
obj['replicates'][0]['library']['biosample']['biosample_ontology']['@id']
# Out:
# '/biosample-types/tissue_UBERON_0002102/'

# %%
needs_fixing = []
for i, row in submitted_experiment.iterrows():
    experiment = server.get_json(row.accession)
    experiment_ontology = experiment['biosample_ontology']['@id']
    for replicate in experiment['replicates']:
        library = replicate['library']
        biosample = library['biosample']
        biosample_ontology = biosample['biosample_ontology']['@id']
        if experiment_ontology != biosample_ontology:
            needs_fixing.append({
                'experiment': row['accession'],
                'biosample': biosample['accession'],
                'experiment_ontology': experiment_ontology,
                'biosample_ontology': biosample_ontology,
            })
            
needs_fixing = pandas.DataFrame(needs_fixing, columns=['experiment', 'biosample', 'biosample_ontology', 'experiment_ontology'])
needs_fixing
# Out:
#       experiment    biosample                       biosample_ontology  \
# 0    ENCSR541RSL  ENCBS087UQX  /biosample-types/tissue_UBERON_0002102/
# 1    ENCSR736TCS  ENCBS623WDD  /biosample-types/tissue_UBERON_0002102/
# 2    ENCSR689LAI  ENCBS674DTZ  /biosample-types/tissue_UBERON_0002102/
# 3    ENCSR544DDX  ENCBS465TNA  /biosample-types/tissue_UBERON_0002102/
# 4    ENCSR093TNN  ENCBS930JPJ  /biosample-types/tissue_UBERON_0002102/
# 5    ENCSR349UAG  ENCBS643JBK  /biosample-types/tissue_UBERON_0002102/
# 6    ENCSR136NWW  ENCBS614UHT  /biosample-types/tissue_UBERON_0002102/
# 7    ENCSR615EFO  ENCBS243TMO  /biosample-types/tissue_UBERON_0002102/
# 8    ENCSR028XBU  ENCBS791QWH  /biosample-types/tissue_UBERON_0002102/
# 9    ENCSR664GEE  ENCBS698LOZ  /biosample-types/tissue_UBERON_0002102/
# 10   ENCSR396CQN  ENCBS182VPK  /biosample-types/tissue_UBERON_0002102/
# 11   ENCSR910QYI  ENCBS670LAF  /biosample-types/tissue_UBERON_0002102/
# 12   ENCSR963CND  ENCBS399KCP  /biosample-types/tissue_UBERON_0002102/
# 13   ENCSR787XXN  ENCBS116ZPR  /biosample-types/tissue_UBERON_0002102/
# 14   ENCSR659EAZ  ENCBS705GWM  /biosample-types/tissue_UBERON_0002102/
# 15   ENCSR504HSK  ENCBS465SPC  /biosample-types/tissue_UBERON_0002102/
# 16   ENCSR399CXZ  ENCBS443BGE  /biosample-types/tissue_UBERON_0002102/
# 17   ENCSR352BTU  ENCBS590SBY  /biosample-types/tissue_UBERON_0002102/
# 18   ENCSR255FEB  ENCBS671DZT  /biosample-types/tissue_UBERON_0002102/
# 19   ENCSR377VMC  ENCBS613UXP  /biosample-types/tissue_UBERON_0002102/
# 20   ENCSR379FZG  ENCBS078BNF  /biosample-types/tissue_UBERON_0002102/
# 21   ENCSR267WBI  ENCBS125BQK  /biosample-types/tissue_UBERON_0002102/
# 22   ENCSR237UYI  ENCBS832YBD  /biosample-types/tissue_UBERON_0002102/
# 23   ENCSR028YNV  ENCBS788QVE  /biosample-types/tissue_UBERON_0002102/
# 24   ENCSR857TMM  ENCBS855POA  /biosample-types/tissue_UBERON_0002102/
# 25   ENCSR988SPE  ENCBS322HUM  /biosample-types/tissue_UBERON_0002102/
# 26   ENCSR631JKM  ENCBS127WVW  /biosample-types/tissue_UBERON_0002102/
# 27   ENCSR627PCC  ENCBS523ZZV  /biosample-types/tissue_UBERON_0002102/
# 28   ENCSR900AGF  ENCBS780PRM  /biosample-types/tissue_UBERON_0002102/
# 29   ENCSR017BPS  ENCBS344CBF  /biosample-types/tissue_UBERON_0002102/
# ..           ...          ...                                      ...
# 415  ENCSR604SKW  ENCBS116PZJ  /biosample-types/tissue_UBERON_0002102/
# 416  ENCSR339GRG  ENCBS022XJX  /biosample-types/tissue_UBERON_0002102/
# 417  ENCSR603IXF  ENCBS661ATN  /biosample-types/tissue_UBERON_0002102/
# 418  ENCSR672DYD  ENCBS307BIQ  /biosample-types/tissue_UBERON_0002102/
# 419  ENCSR764THN  ENCBS390VEX  /biosample-types/tissue_UBERON_0002102/
# 420  ENCSR590EFF  ENCBS035QAD  /biosample-types/tissue_UBERON_0002102/
# 421  ENCSR064IZZ  ENCBS284YHE  /biosample-types/tissue_UBERON_0002102/
# 422  ENCSR946DVF  ENCBS664EDR  /biosample-types/tissue_UBERON_0002102/
# 423  ENCSR278FAK  ENCBS203BQW  /biosample-types/tissue_UBERON_0002102/
# 424  ENCSR093MWP  ENCBS501LNF  /biosample-types/tissue_UBERON_0002102/
# 425  ENCSR374MNZ  ENCBS333ZTE  /biosample-types/tissue_UBERON_0002102/
# 426  ENCSR393NGF  ENCBS787TFV  /biosample-types/tissue_UBERON_0002102/
# 427  ENCSR634JAJ  ENCBS800TVB  /biosample-types/tissue_UBERON_0002102/
# 428  ENCSR993MPV  ENCBS462NSA  /biosample-types/tissue_UBERON_0002102/
# 429  ENCSR007BOX  ENCBS115FEZ  /biosample-types/tissue_UBERON_0002102/
# 430  ENCSR211UFK  ENCBS166HIA  /biosample-types/tissue_UBERON_0002102/
# 431  ENCSR318KJR  ENCBS146YAE  /biosample-types/tissue_UBERON_0002102/
# 432  ENCSR932MVN  ENCBS878JIH  /biosample-types/tissue_UBERON_0002102/
# 433  ENCSR631VWE  ENCBS041MHT  /biosample-types/tissue_UBERON_0002102/
# 434  ENCSR631JZU  ENCBS083ANG  /biosample-types/tissue_UBERON_0002102/
# 435  ENCSR127OBU  ENCBS316PAR  /biosample-types/tissue_UBERON_0002102/
# 436  ENCSR897KBM  ENCBS981FZE  /biosample-types/tissue_UBERON_0002102/
# 437  ENCSR521HKA  ENCBS901FSE  /biosample-types/tissue_UBERON_0002102/
# 438  ENCSR778QVQ  ENCBS278SKS  /biosample-types/tissue_UBERON_0002102/
# 439  ENCSR256TUD  ENCBS493ZCR  /biosample-types/tissue_UBERON_0002102/
# 440  ENCSR656OSM  ENCBS518JPI  /biosample-types/tissue_UBERON_0002102/
# 441  ENCSR895JVE  ENCBS621YMR  /biosample-types/tissue_UBERON_0002102/
# 442  ENCSR827XKP  ENCBS888SGV  /biosample-types/tissue_UBERON_0002102/
# 443  ENCSR237FNI  ENCBS532XFN  /biosample-types/tissue_UBERON_0002102/
# 444  ENCSR312YOD  ENCBS913XJP  /biosample-types/tissue_UBERON_0002102/
#
#                               experiment_ontology
# 0    /biosample-types/single_cell_UBERON_0002102/
# 1    /biosample-types/single_cell_UBERON_0002102/
# 2    /biosample-types/single_cell_UBERON_0002102/
# 3    /biosample-types/single_cell_UBERON_0002102/
# 4    /biosample-types/single_cell_UBERON_0002102/
# 5    /biosample-types/single_cell_UBERON_0002102/
# 6    /biosample-types/single_cell_UBERON_0002102/
# 7    /biosample-types/single_cell_UBERON_0002102/
# 8    /biosample-types/single_cell_UBERON_0002102/
# 9    /biosample-types/single_cell_UBERON_0002102/
# 10   /biosample-types/single_cell_UBERON_0002102/
# 11   /biosample-types/single_cell_UBERON_0002102/
# 12   /biosample-types/single_cell_UBERON_0002102/
# 13   /biosample-types/single_cell_UBERON_0002102/
# 14   /biosample-types/single_cell_UBERON_0002102/
# 15   /biosample-types/single_cell_UBERON_0002102/
# 16   /biosample-types/single_cell_UBERON_0002102/
# 17   /biosample-types/single_cell_UBERON_0002102/
# 18   /biosample-types/single_cell_UBERON_0002102/
# 19   /biosample-types/single_cell_UBERON_0002102/
# 20   /biosample-types/single_cell_UBERON_0002102/
# 21   /biosample-types/single_cell_UBERON_0002102/
# 22   /biosample-types/single_cell_UBERON_0002102/
# 23   /biosample-types/single_cell_UBERON_0002102/
# 24   /biosample-types/single_cell_UBERON_0002102/
# 25   /biosample-types/single_cell_UBERON_0002102/
# 26   /biosample-types/single_cell_UBERON_0002102/
# 27   /biosample-types/single_cell_UBERON_0002102/
# 28   /biosample-types/single_cell_UBERON_0002102/
# 29   /biosample-types/single_cell_UBERON_0002102/
# ..                                            ...
# 415  /biosample-types/single_cell_UBERON_0002102/
# 416  /biosample-types/single_cell_UBERON_0002102/
# 417  /biosample-types/single_cell_UBERON_0002102/
# 418  /biosample-types/single_cell_UBERON_0002102/
# 419  /biosample-types/single_cell_UBERON_0002102/
# 420  /biosample-types/single_cell_UBERON_0002102/
# 421  /biosample-types/single_cell_UBERON_0002102/
# 422  /biosample-types/single_cell_UBERON_0002102/
# 423  /biosample-types/single_cell_UBERON_0002102/
# 424  /biosample-types/single_cell_UBERON_0002102/
# 425  /biosample-types/single_cell_UBERON_0002102/
# 426  /biosample-types/single_cell_UBERON_0002102/
# 427  /biosample-types/single_cell_UBERON_0002102/
# 428  /biosample-types/single_cell_UBERON_0002102/
# 429  /biosample-types/single_cell_UBERON_0002102/
# 430  /biosample-types/single_cell_UBERON_0002102/
# 431  /biosample-types/single_cell_UBERON_0002102/
# 432  /biosample-types/single_cell_UBERON_0002102/
# 433  /biosample-types/single_cell_UBERON_0002102/
# 434  /biosample-types/single_cell_UBERON_0002102/
# 435  /biosample-types/single_cell_UBERON_0002102/
# 436  /biosample-types/single_cell_UBERON_0002102/
# 437  /biosample-types/single_cell_UBERON_0002102/
# 438  /biosample-types/single_cell_UBERON_0002102/
# 439  /biosample-types/single_cell_UBERON_0002102/
# 440  /biosample-types/single_cell_UBERON_0002102/
# 441  /biosample-types/single_cell_UBERON_0002102/
# 442  /biosample-types/single_cell_UBERON_0002102/
# 443  /biosample-types/single_cell_UBERON_0002102/
# 444  /biosample-types/single_cell_UBERON_0002102/
#
# [445 rows x 4 columns]
